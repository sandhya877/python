# %%
import numpy as np
import pandas as pd
import os,os.path
import cv2
import matplotlib.pyplot as plt

# %%
classes={"10":10,"20":20}

# %%
import cv2
X = []
Y = []
for cls in classes:
    path1 = "C:/Users/SANDHYA/Downloads/archive/indian_currency_new/training/"
    pth=os.path.join(path1,cls)
    print(pth)
    for j in os.listdir(pth):
        img = cv2.imread(pth+'/'+j)
        X.append(img)
        
        Y.append(classes[cls])
# Out:
# C:/Users/SANDHYA/Downloads/archive/indian_currency_new/training/10
# C:/Users/SANDHYA/Downloads/archive/indian_currency_new/training/20

# %%
print(type(X[0]))
# Out:
# <class 'numpy.ndarray'>

# %%
X
# Out:
# [array([[[255, 255, 255],
#          [255, 255, 255],
#          [255, 255, 255],
#          ...,
#          [255, 255, 255],
#          [255, 255, 255],
#          [255, 255, 255]],
#
#         [[255, 255, 255],
#          [255, 255, 255],
#          [255, 255, 255],
#          ...,
#          [255, 255, 255],
#          [255, 255, 255],
#          [255, 255, 255]],
#
#         [[255, 255, 255],
#          [255, 255, 255],
#          [255, 255, 255],
#          ...,
#          [255, 255, 255],
#          [255, 255, 255],
#          [255, 255, 255]],
#
#         ...,
#
#         [[ 61,  61,  61],
#          [ 61,  61,  61],
#          [ 61,  61,  61],
#          ...,
#          [ 61,  61,  61],
#          [ 61,  61,  61],
#          [ 61,  61,  61]],
#
#         [[ 61,  61,  61],
#          [ 61,  61,  61],
#          [ 61,  61,  61],
#          ...,
#          [ 61,  61,  61],
#          [ 61,  61,  61],
#          [ 61,  61,  61]],
#
#         [[ 61,  61,  61],
# ...

# %%
np.unique(Y)
# Out:
# array([10, 20])

# %%
print(type(X))
# Out:
# <class 'numpy.ndarray'>

# %%
print(X[0].ndim)
# Out:
# 3

# %%
X=np.array(X,dtype=np.ndarray)
Y=np.array(Y,dtype=np.ndarray)

# %%
X_updated = X.reshape(len(X), -1)

# %%
print(type(X_updated))
# Out:
# <class 'numpy.ndarray'>

# %%
Z=pd.Series(Y).value_counts()
Z
# Out:
# 10    87
# 20    75
# dtype: int64

# %%
plt.figure(figsize=(5,5))
plt.pie(Z,labels=["10 RS notes","20 RS notes"],autopct="%.2f%%")
plt.show()

# %%
print(os.listdir(pth))
# Out:
# ['10.jpg', '11.jpg', '12.jpg', '13.jpg', '15.jpg', '16.jpg', '18.jpg', '19.jpg', '2.jpg', '21.jpg', '22.jpg', '23.jpg', '24.jpg', '26.jpg', '27.jpg', '28.jpg', '29.jpg', '3.jpg', '31.jpg', '33.jpg', '34.jpg', '35.jpg', '36.jpg', '37.jpg', '38.jpg', '39.jpg', '4.jpg', '40.jpg', '41.jpg', '42.jpg', '43.jpg', '44.jpg', '45.jpg', '46.jpg', '47.jpg', '48.jpg', '49.jpg', '5.jpg', '50.jpg', '51.jpg', '52.jpg', '54.jpg', '55.jpg', '57.jpg', '58.jpg', '59.jpg', '6.jpg', '60.jpg', '61.jpg', '62.jpg', '63.jpg', '64.jpg', '65.jpg', '66.jpg', '67.jpg', '68.jpg', '69.jpg', '70.jpg', '71.jpg', '72.jpg', '73.jpg', '74.jpg', '75.jpg', '76.jpg', '77.jpg', '78.jpg', '79.jpg', '8.jpg', '80.jpg', '81.jpg', '82.jpg', '83.jpg', '84.jpg', '85.jpg', '9.jpg']

# %%
x_train,x_test,y_train,y_test=train_test_split(X_updated,Y,random_state=10,test_size=0.25)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC

# %%
clf = SVC(gamma=0.01,C=10,kernel='poly')
clf.fit(x_train,y_train.values.tolist())
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [64], in <cell line: 2>()
#       1 clf = SVC(gamma=0.01,C=10,kernel='poly')
# ----> 2 clf.fit(x_train,y_train.values.tolist())
#
# AttributeError: 'numpy.ndarray' object has no attribute 'values'

# %%
l=[2,4,6,8]
l.insert(8,6)

# %%
l
# Out:
# [2, 4, 6, 8, 6]

# %%
l.insert(3,"hello")

# %%
l
# Out:
# [2, 4, 6, 'hello', 8, 6]

# %%
spam=["a","b","c","d"]
spam[int(int('3' * 2) / 11)]
# Out:
# 'd'

# %%
spam[-1]
# Out:
# 'd'

# %%
spam[:2]
# Out:
# ['a', 'b']

# %%
list =[3.14, 'cat', 11, 'cat', True]

# %%
list.remove('cat')

# %%
list
# Out:
# [3.14, 11, 'cat', True]

# %%
a=[3,8]

# %%
l=list+a

# %%
l
# Out:
# [3.14, 11, 'cat', True, 3, 8]

# %%
a="678gh"

# %%
type(a)
# Out:
# str

# %%
a=(42,)

# %%
type(a)
# Out:
# tuple
